# %% [markdown]
# # Lecture 8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
VarNames=["signal", "l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi", "MET", "MET_phi", "MET_rel", "axial_MET", "M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos_theta_r1"]
RawNames=["l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi", "MET", "MET_phi"]
FeatureNames=list(set(VarNames[1:]).difference(RawNames))

# %%
filename="../Lecture.6/SUSY.csv"
df = pd.read_csv(filename, dtype='float64', names=VarNames)

# %%
df_sig=df[df.signal==1]
df_bkg=df[df.signal==0]

# %% [markdown]
# ## Create Data Like Sample

# %%
import math
n_bkg_expected = 100
n_sig_expected = 10

data = df_sig[:n_sig_expected]["M_TR_2"].tolist()+df_bkg[:n_bkg_expected]["M_TR_2"].tolist()

c , bin_edges= np.histogram(data,bins=20)
bin_width = bin_edges[1]-bin_edges[0]
bin_centers = 0.5*(bin_edges[1:]+bin_edges[:-1])
error    = np.sqrt(c)

plt.errorbar(bin_centers, c, yerr=error, marker="o")
plt.show()

# %% [markdown]
# ## Optain Probability Distributions from Simulation

# %%
c_bkg_sim, sim_bin = np.histogram(df_bkg["M_TR_2"],bins=100) 
plt.step(sim_bin[1:],c_bkg_sim)

# %%
c_sig_sim, sim_bin = np.histogram(df_sig["M_TR_2"],bins=sim_bin)
plt.step(sim_bin[1:],c_sig_sim)

# %%
bin_size_sim = sim_bin[1]-sim_bin[0]
integral = sum(c_bkg_sim) * bin_size_sim
c_bkg_sim_normalized = (n_bkg_expected / integral ) * c_bkg_sim
plt.step(sim_bin[1:],c_bkg_sim_normalized)

# %%
integral = sum(c_sig_sim) * bin_size_sim
c_sig_sim_normalized = (n_sig_expected / integral ) * c_sig_sim
plt.step(sim_bin[1:],c_sig_sim_normalized)

# %% [markdown]
# ## Combine to Compare Data and Simulation

# %%
plt.errorbar(bin_centers, c, yerr=error, marker="o",label="data")
plt.yscale("log")
plt.step(sim_bin[1:],c_bkg_sim_normalized*bin_width,label="background")
plt.step(sim_bin[1:],(c_bkg_sim_normalized+c_sig_sim_normalized)*bin_width,label="background + signal")
plt.legend()
plt.show()

# %% [markdown]
# ## Calculate TPR / FPR

# %%
_=plt.hist(df_sig["M_TR_2"],bins=100,histtype="step")

# %%
TPR,bins_sig,_=plt.hist(df_sig["M_TR_2"],bins=100,histtype="step",cumulative=-1,density=True)

# %%
FPR,bins_sig,_=plt.hist(df_bkg["M_TR_2"],bins=bins_sig,histtype="step",cumulative=-1,density=True)

# %% [markdown]
# ## Compute Significance

# %% [markdown]
# Assume 3 different scenarios corresponding to different numbers of signal and background events expected in data:
#
# 1. Expect $N_S=10$, $N_B=100$.
# 1. Expect $N_S=100$, $N_B=1000$.
# 1. Expect $N_S=1000$, $N_B=10000$.
# 1. Expect $N_S=10000$, $N_B=100000$.
#
# Plot the significance ($\sigma_{S'}$) for each observable as function of $x_c$ for each scenario, where
#
# $\sigma_{S'}= \frac{N'_S}{\sqrt{N'_S+N'_B}}$
#
# and $N'_{S,B} = \epsilon_{S,B}(x_c) * N_{S,B}$.

# %%
n_bkg_expected = 10000
n_sig_expected = 1000

n_sig_expected_prime = n_sig_expected * TPR
n_bkg_expected_prime = n_bkg_expected * FPR

sig = n_sig_expected_prime/ np.sqrt(n_sig_expected_prime + n_bkg_expected_prime )
plt.step(bins_sig[:-1],sig)

# %%
np.argmax(sig)
# Out:
# 9

# %%
scenarios = { "1": (10,100), 
              "2": (100,1000),
              "3": (1000,10000),
              "4": (10000,100000)
            }

def compare_significance(scenarios,log=False):
    max_sigs=dict()
    for name, (n_sig_expected, n_bkg_expected) in scenarios.items():

        n_sig_expected_prime = n_sig_expected * TPR
        n_bkg_expected_prime = n_bkg_expected * FPR

        sig = n_sig_expected_prime/ np.sqrt(n_sig_expected_prime + n_bkg_expected_prime )
        plt.step(bins_sig[:-1],sig,label=name)
    
        max_i=np.argmax(sig)
        max_sigs[name]=(max_i,n_sig_expected_prime[max_i],n_bkg_expected_prime[max_i],sig[max_i],bins_sig[max_i])
        
    if log:
        plt.yscale("log")
    plt.legend()
    plt.show()
    
    return max_sigs

max_sigs = compare_significance(scenarios)
max_sigs
# Out:
# {'1': (9,
#   3.6321277788923725,
#   4.698005878683211,
#   1.258447591175229,
#   1.350293831230374),
#  '2': (9,
#   36.32127778892372,
#   46.9800587868321,
#   3.9795607040661367,
#   1.350293831230374),
#  '3': (9,
#   363.2127778892372,
#   469.80058786832103,
#   12.584475911752289,
#   1.350293831230374),
#  '4': (9,
#   3632.127778892372,
#   4698.0058786832105,
#   39.795607040661366,
#   1.350293831230374)}

# %%
from IPython.display import HTML, display
import tabulate
display(HTML(tabulate.tabulate(max_sigs.values(), 
                               tablefmt='html',
                               headers=["bin i",'N sig','N bkg','sig','x_c'])))
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  bin i</th><th style="text-align: right;">     N sig</th><th style="text-align: right;">     N bkg</th><th style="text-align: right;">     sig</th><th style="text-align: right;">    x_c</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">      9</td><td style="text-align: right;">   3.63213</td><td style="text-align: right;">   4.69801</td><td style="text-align: right;"> 1.25845</td><td style="text-align: right;">1.35029</td></tr>
# <tr><td style="text-align: right;">      9</td><td style="text-align: right;">  36.3213 </td><td style="text-align: right;">  46.9801 </td><td style="text-align: right;"> 3.97956</td><td style="text-align: right;">1.35029</td></tr>
# <tr><td style="text-align: right;">      9</td><td style="text-align: right;"> 363.213  </td><td style="text-align: right;"> 469.801  </td><td style="text-align: right;">12.5845 </td><td style="text-align: right;">1.35029</td></tr>
# <tr><td style="text-align: right;">      9</td><td style="text-align: right;">3632.13   </td><td style="text-align: right;">4698.01   </td><td style="text-align: right;">39.7956 </td><td style="text-align: right;">1.35029</td></tr>
# </tbody>
# </table>

# %%
def compare_significance(scenarios,log=False):
    max_sigs=dict()
    table=list()
    
    for name, (n_sig_expected, n_bkg_expected) in scenarios.items():

        n_sig_expected_prime = n_sig_expected * TPR
        n_bkg_expected_prime = n_bkg_expected * FPR

        sig = n_sig_expected_prime/ np.sqrt(n_sig_expected_prime + n_bkg_expected_prime )
        plt.step(bins_sig[:-1],sig,label=name+" "+str((n_sig_expected, n_bkg_expected)))
    
        max_i=np.argmax(sig)
        max_sigs[name]=(max_i,n_sig_expected_prime[max_i],n_bkg_expected_prime[max_i],sig[max_i],bins_sig[max_i])
        table.append((name,n_sig_expected, n_bkg_expected, 
                      TPR[max_i],FPR[max_i],
                      n_sig_expected_prime[max_i],n_bkg_expected_prime[max_i],sig[max_i],bins_sig[max_i],max_i)
        )
    if log:
        plt.yscale("log")
    plt.legend()
    plt.show()
    
    display(HTML(tabulate.tabulate(table, tablefmt='html',
                                   headers=["Name",'N sig','N bkg',"TPR","FPR","N sig'","N bkg'",'sig','x_c',"bin i"])))
    return max_sigs

# %%
scenarios = { "1": (100,100), 
              "2": (100,1000),
              "3": (1000,10000),
            }
_=compare_significance(scenarios)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">     TPR</th><th style="text-align: right;">      FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">     x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">0.883743</td><td style="text-align: right;">0.674869 </td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;"> 7.07876</td><td style="text-align: right;">0.600709</td><td style="text-align: right;">      4</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">0.363213</td><td style="text-align: right;">0.0469801</td><td style="text-align: right;"> 36.3213</td><td style="text-align: right;"> 46.9801</td><td style="text-align: right;"> 3.97956</td><td style="text-align: right;">1.35029 </td><td style="text-align: right;">      9</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">   1000</td><td style="text-align: right;">  10000</td><td style="text-align: right;">0.363213</td><td style="text-align: right;">0.0469801</td><td style="text-align: right;">363.213 </td><td style="text-align: right;">469.801 </td><td style="text-align: right;">12.5845 </td><td style="text-align: right;">1.35029 </td><td style="text-align: right;">      9</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Generalize
#
# This function above isn't general, in the sense that it relies on various objects we computed before it (namely TPR and FPR. Lets generalize to get a function that can make a similar plot for any observeable.
#
# One problem is that we are using `matplotlib` to compute the TPR/FPR, eventhough we never plot it. Let's instead compute it with `numpy`:

# %%
# Matplotlib
TPR,bins_sig,_=plt.hist(df_sig["M_TR_2"],bins=100,histtype="step",cumulative=-1,density=True)

# %%
# compute with numpy
hist,bins_sig=np.histogram(df_sig["M_TR_2"],bins=100,density=True)
TPR = np.cumsum(hist[::-1])[::-1] * (bins_sig[1]-bins_sig[0])

# plot with matplotlib
plt.step(bins_sig[:-1],TPR)
plt.show()

# %% [markdown]
# Lets write this into a function:

# %%
def compute_rate(d,bins=100):
    hist,bins_=np.histogram(d,bins=bins,density=True)
    R = np.cumsum(hist[::-1])[::-1] * (bins_[1]-bins_[0])
    return R,bins_

# %% [markdown]
# Note that this function onlhy works for the first possible selection criteria (from your lab):
#
# 1. $x > x_c$
# 2. $x < x_c$
# 3. $|x - x_0| > x_c$
# 4. $|x - x_0| < x_c$
#
# And actually, scenarios 3 and 4 are more challenging to implement.

# %% [markdown]
# Now put it all together:

# %%
def compare_significance(df_sig, df_bkg,
                         obs_name,
                         scenarios,bins=100,log=False):
        
    TPR,bins_sig = compute_rate(df_sig[obs_name],bins=bins)
    FPR,bins_sig = compute_rate(df_bkg[obs_name],bins=bins_sig)
    
    max_sigs=dict()
    table=list()
    
    for name, (n_sig_expected, n_bkg_expected) in scenarios.items():

        n_sig_expected_prime = n_sig_expected * TPR
        n_bkg_expected_prime = n_bkg_expected * FPR

        sig = n_sig_expected_prime/ np.sqrt(n_sig_expected_prime + n_bkg_expected_prime )
        plt.step(bins_sig[:-1],sig,label=name+" "+str((n_sig_expected, n_bkg_expected)))
    
        max_i=np.argmax(sig)
        max_sigs[name]=(max_i,n_sig_expected_prime[max_i],n_bkg_expected_prime[max_i],sig[max_i],bins_sig[max_i])
        table.append((name,n_sig_expected, n_bkg_expected, 
                      TPR[max_i],FPR[max_i],
                      n_sig_expected_prime[max_i],n_bkg_expected_prime[max_i],sig[max_i],bins_sig[max_i],max_i)
        )
    if log:
        plt.yscale("log")
    plt.legend()
    plt.show()
    
    display(HTML(tabulate.tabulate(table, tablefmt='html',
                                   headers=["Name",'N sig','N bkg',"TPR","FPR","N sig'","N bkg'",'sig','x_c',"bin i"])))
    return max_sigs

# %%
scenarios = { "1": (100,100), 
              "2": (100,1000),
              "3": (1000,10000),
            }
_=compare_significance(df_sig,df_bkg,"M_TR_2",scenarios)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">     TPR</th><th style="text-align: right;">      FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">     x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">0.883743</td><td style="text-align: right;">0.674869 </td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;"> 7.07876</td><td style="text-align: right;">0.600709</td><td style="text-align: right;">      4</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">0.363213</td><td style="text-align: right;">0.0469801</td><td style="text-align: right;"> 36.3213</td><td style="text-align: right;"> 46.9801</td><td style="text-align: right;"> 3.97956</td><td style="text-align: right;">1.35029 </td><td style="text-align: right;">      9</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">   1000</td><td style="text-align: right;">  10000</td><td style="text-align: right;">0.363213</td><td style="text-align: right;">0.0469801</td><td style="text-align: right;">363.213 </td><td style="text-align: right;">469.801 </td><td style="text-align: right;">12.5845 </td><td style="text-align: right;">1.35029 </td><td style="text-align: right;">      9</td></tr>
# </tbody>
# </table>

# %%
my_obs= ['MET',
 'MET_phi',
 'MET_rel',
 'axial_MET',
 'M_R',
 'M_TR_2',
 'R',
 'MT2',
 'S_R',
 'M_Delta_R',
 'dPhi_r_b',
 'cos_theta_r1']

# %%
for obs in my_obs:
    print(obs)
    _=compare_significance(df_sig,df_bkg,obs,scenarios)
# Out:
# MET
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">     TPR</th><th style="text-align: right;">      FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">     x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">0.899029</td><td style="text-align: right;">0.712199 </td><td style="text-align: right;"> 89.9029</td><td style="text-align: right;"> 71.2199</td><td style="text-align: right;"> 7.08264</td><td style="text-align: right;">0.421632</td><td style="text-align: right;">      2</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">0.349463</td><td style="text-align: right;">0.0198365</td><td style="text-align: right;"> 34.9463</td><td style="text-align: right;"> 19.8365</td><td style="text-align: right;"> 4.72149</td><td style="text-align: right;">1.47506 </td><td style="text-align: right;">      7</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">   1000</td><td style="text-align: right;">  10000</td><td style="text-align: right;">0.349463</td><td style="text-align: right;">0.0198365</td><td style="text-align: right;">349.463 </td><td style="text-align: right;">198.365 </td><td style="text-align: right;">14.9307 </td><td style="text-align: right;">1.47506 </td><td style="text-align: right;">      7</td></tr>
# </tbody>
# </table>
# MET_phi
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">  TPR</th><th style="text-align: right;">  FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">    sig</th><th style="text-align: right;">     x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">     100</td><td style="text-align: right;">     100</td><td style="text-align: right;">7.07107</td><td style="text-align: right;">-1.72712</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">     100</td><td style="text-align: right;">    1000</td><td style="text-align: right;">3.01511</td><td style="text-align: right;">-1.72712</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">   1000</td><td style="text-align: right;">  10000</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1000</td><td style="text-align: right;">   10000</td><td style="text-align: right;">9.53463</td><td style="text-align: right;">-1.72712</td><td style="text-align: right;">      0</td></tr>
# </tbody>
# </table>
# MET_rel
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">     TPR</th><th style="text-align: right;">       FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">   N bkg&#x27;</th><th style="text-align: right;">    sig</th><th style="text-align: right;">        x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">1       </td><td style="text-align: right;">1         </td><td style="text-align: right;">100     </td><td style="text-align: right;">100      </td><td style="text-align: right;">7.07107</td><td style="text-align: right;">7.69348e-08</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">0
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">  TPR</th><th style="text-align: right;">  FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">    sig</th><th style="text-align: right;">        x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">     100</td><td style="text-align: right;">     100</td><td style="text-align: right;">7.07107</td><td style="text-align: right;">1.50257e-07</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">     100</td><td style="text-align: right;">    1000</td><td style="text-align: right;">3.01511</td><td style="text-align: right;">1.50257e-07</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">   1000</td><td style="text-align: right;">  10000</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1000</td><td style="text-align: right;">   10000</td><td style="text-align: right;">9.53463</td><td style="text-align: right;">1.50257e-07</td><td style="text-align: right;">      0</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## Making Selections
#
# Recall that with Pandas, you can select a subset of your data:

# %%
df_sig["M_TR_2"]>1.35029
# Out:
# 1          False
# 2          False
# 3          False
# 4          False
# 8           True
#            ...
# 4999986    False
# 4999988     True
# 4999991    False
# 4999995     True
# 4999998    False
# Name: M_TR_2, Length: 2287827, dtype: bool

# %% [markdown]
# Some basic checks:

# %%
sum(df_sig["M_TR_2"]>1.35029)
# Out:
# 830973

# %%
df_sig.shape
# Out:
# (2287827, 19)

# %%
sum(df_sig["M_TR_2"]>1.35029)/df_sig.shape[0]
# Out:
# 0.3632149633691708

# %% [markdown]
# Now lets select on one variable and look how the significance changes:

# %%
df_sig_1 = df_sig[df_sig["M_TR_2"]>1.35029]
df_bkg_1 = df_bkg[df_bkg["M_TR_2"]>1.35029]

# %%
print(df_sig_1.shape)
print(df_bkg_1.shape)
# Out:
# (830973, 19)
# (127420, 19)

# %%
scenarios = { "1": (100,100), 
              "2": (100,1000),
              "3": (1000,10000),
            }
_=compare_significance(df_sig,df_bkg,"M_Delta_R",scenarios)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">  TPR</th><th style="text-align: right;">  FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">    sig</th><th style="text-align: right;">       x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">     100</td><td style="text-align: right;">     100</td><td style="text-align: right;">7.07107</td><td style="text-align: right;">0.00445562</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">     100</td><td style="text-align: right;">    1000</td><td style="text-align: right;">3.01511</td><td style="text-align: right;">0.00445562</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">   1000</td><td style="text-align: right;">  10000</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1000</td><td style="text-align: right;">   10000</td><td style="text-align: right;">9.53463</td><td style="text-align: right;">0.00445562</td><td style="text-align: right;">      0</td></tr>
# </tbody>
# </table>

# %%
scenarios = { "1": (100,100), 
              "2": (100,1000),
              "3": (1000,10000),
            }
_=compare_significance(df_sig_1,df_bkg_1,"M_Delta_R",scenarios)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">  TPR</th><th style="text-align: right;">  FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">    sig</th><th style="text-align: right;">       x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">     100</td><td style="text-align: right;">     100</td><td style="text-align: right;">7.07107</td><td style="text-align: right;">0.00447584</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">     100</td><td style="text-align: right;">    1000</td><td style="text-align: right;">3.01511</td><td style="text-align: right;">0.00447584</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">   1000</td><td style="text-align: right;">  10000</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1000</td><td style="text-align: right;">   10000</td><td style="text-align: right;">9.53463</td><td style="text-align: right;">0.00447584</td><td style="text-align: right;">      0</td></tr>
# </tbody>
# </table>

# %% [markdown]
# We didn't do something correctly here... can someone tell me what?

# %%
res=compare_significance(df_sig,df_bkg,"M_TR_2",scenarios)
res
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">  N sig</th><th style="text-align: right;">  N bkg</th><th style="text-align: right;">     TPR</th><th style="text-align: right;">      FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">     x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;">    100</td><td style="text-align: right;">    100</td><td style="text-align: right;">0.883743</td><td style="text-align: right;">0.674869 </td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;"> 7.07876</td><td style="text-align: right;">0.600709</td><td style="text-align: right;">      4</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;">    100</td><td style="text-align: right;">   1000</td><td style="text-align: right;">0.363213</td><td style="text-align: right;">0.0469801</td><td style="text-align: right;"> 36.3213</td><td style="text-align: right;"> 46.9801</td><td style="text-align: right;"> 3.97956</td><td style="text-align: right;">1.35029 </td><td style="text-align: right;">      9</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">   1000</td><td style="text-align: right;">  10000</td><td style="text-align: right;">0.363213</td><td style="text-align: right;">0.0469801</td><td style="text-align: right;">363.213 </td><td style="text-align: right;">469.801 </td><td style="text-align: right;">12.5845 </td><td style="text-align: right;">1.35029 </td><td style="text-align: right;">      9</td></tr>
# </tbody>
# </table>
# {'1': (4,
#   88.37433949332707,
#   67.48694404337188,
#   7.078757857761016,
#   0.6007090518251061),
#  '2': (9,
#   36.32127778892372,
#   46.9800587868321,
#   3.9795607040661367,
#   1.350293831230374),
#  '3': (9,
#   363.2127778892372,
#   469.80058786832103,
#   12.584475911752289,
#   1.350293831230374)}

# %%
bin_i,N_sig,N_bkg,sig,M_TR_2_c=res["1"]

# %%
scenarios = { "1": (N_sig,N_bkg), 
              "2": (N_sig,10*N_bkg),
              "3": (10*N_sig,10*N_bkg),
            }

df_sig_1 = df_sig[df_sig["M_TR_2"]>M_TR_2_c]
df_bkg_1 = df_bkg[df_bkg["M_TR_2"]>M_TR_2_c]

_=compare_significance(df_sig_1,df_bkg_1,"M_Delta_R",scenarios)
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">   N sig</th><th style="text-align: right;">   N bkg</th><th style="text-align: right;">  TPR</th><th style="text-align: right;">  FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">       x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;"> 7.07876</td><td style="text-align: right;">0.00447584</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;">674.869 </td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;">674.869 </td><td style="text-align: right;"> 3.19885</td><td style="text-align: right;">0.00447584</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">883.743 </td><td style="text-align: right;">674.869 </td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">883.743 </td><td style="text-align: right;">674.869 </td><td style="text-align: right;">22.385  </td><td style="text-align: right;">0.00447584</td><td style="text-align: right;">      0</td></tr>
# </tbody>
# </table>

# %%
for obs in my_obs:
    print(obs)
    _=compare_significance(df_sig_1,df_bkg_1,obs,scenarios)
# Out:
# MET
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">   N sig</th><th style="text-align: right;">   N bkg</th><th style="text-align: right;">     TPR</th><th style="text-align: right;">      FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">      x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;">1       </td><td style="text-align: right;">1        </td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;"> 7.07876</td><td style="text-align: right;">0.0486049</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;">674.869 </td><td style="text-align: right;">0.366068</td><td style="text-align: right;">0.0237658</td><td style="text-align: right;"> 32.351 </td><td style="text-align: right;"> 16.0388</td><td style="text-align: right;"> 4.65062</td><td style="text-align: right;">1.52002  </td><td style="text-align: right;">      7</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">883.743 </td><td style="text-align: right;">674.869 </td><td style="text-align: right;">1       </td><td style="text-align: right;">1        </td><td style="text-align: right;">883.743 </td><td style="text-align: right;">674.869 </td><td style="text-align: right;">22.385  </td><td style="text-align: right;">0.0486049</td><td style="text-align: right;">      0</td></tr>
# </tbody>
# </table>
# MET_phi
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">   N sig</th><th style="text-align: right;">   N bkg</th><th style="text-align: right;">  TPR</th><th style="text-align: right;">  FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">     x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;"> 7.07876</td><td style="text-align: right;">-1.72712</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;">674.869 </td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;">674.869 </td><td style="text-align: right;"> 3.19885</td><td style="text-align: right;">-1.72712</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">883.743 </td><td style="text-align: right;">674.869 </td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">883.743 </td><td style="text-align: right;">674.869 </td><td style="text-align: right;">22.385  </td><td style="text-align: right;">-1.72712</td><td style="text-align: right;">      0</td></tr>
# </tbody>
# </table>
# MET_rel
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">   N sig</th><th style="text-align: right;">   N bkg</th><th style="text-align: right;">  TPR</th><th style="text-align: right;">  FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">  N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">        x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;"> 7.07876</td><td style="text-align: right;">7.69348e-08</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;">674.869 </td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;">674.869 </td><td style="text-align: right;"> 3.19885</td><td style="text-align: right;">7.69348e-08</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     3</td><td style="text-align: right;">883.743 </td><td style="text-align: right;">674.869 </td><td style="text-align: right;">    1</td><td style="text-align: right;">    1</td><td style="text-align: right;">883.743 </td><td style="text-align: right;">674.869 </td><td style="text-align: right;">22.385  </td><td style="text-align: right;">7.69348e-08</td><td style="text-align: right;">      0</td></tr>
# </tbody>
# </table>
# axial_MET
# <table>
# <thead>
# <tr><th style="text-align: right;">  Name</th><th style="text-align: right;">   N sig</th><th style="text-align: right;">   N bkg</th><th style="text-align: right;">     TPR</th><th style="text-align: right;">       FPR</th><th style="text-align: right;">  N sig&#x27;</th><th style="text-align: right;">   N bkg&#x27;</th><th style="text-align: right;">     sig</th><th style="text-align: right;">     x_c</th><th style="text-align: right;">  bin i</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">     1</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869</td><td style="text-align: right;">1       </td><td style="text-align: right;">1         </td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;"> 67.4869 </td><td style="text-align: right;"> 7.07876</td><td style="text-align: right;">-16.7186</td><td style="text-align: right;">      0</td></tr>
# <tr><td style="text-align: right;">     2</td><td style="text-align: right;"> 88.3743</td><td style="text-align: right;">674.869 </td><td style="text-align: right;">0